# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv")

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df.isna().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df[df["origin"] == "Asia"].fuel_efficiency_mpg.max()
# Out:
# np.float64(41.2)

# %%
df["horsepower"].median()
# Out:
# np.float64(254.0)

# %%
horsepower_count = df.groupby("horsepower")["horsepower"].count()

# %%
horsepower_count
# Out:
# horsepower
# 171.0    1
# 174.0    1
# 175.0    1
# 178.0    1
# 181.0    4
#         ..
# 328.0    1
# 329.0    3
# 330.0    1
# 332.0    3
# 334.0    2
# Name: horsepower, Length: 153, dtype: int64

# %%
[horsepower_count[x] for x in [horsepower_count == horsepower_count.max()]]
# Out:
# [horsepower
#  252.0    174
#  Name: horsepower, dtype: int64]

# %%
df["horsepower"].fillna(252.0).median()
# Out:
# np.float64(252.0)

# %%
X = df[df["origin"] == "Asia"][["vehicle_weight", "model_year"]].head(n=7).values

# %%
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XTX = np.linalg.inv(X.T @ X)

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200]).T

# %%
w = XTX @ X.T @ y

# %%
w.sum()
# Out:
# np.float64(0.36919696904925486)
